# %% [markdown]
# ## **연도별 미세먼지 수치 데이터 정제**

# %%
import pandas as pd

# %%
#경고 메시지 표시 안하게 설정
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
# pd.options.display.float_format = '{:.1f}'.format

# %%
p = pd.read_csv('data/f_pm10.csv', encoding='CP949', header=0, engine='python')
p

# %%
p = p.drop(['광역시도', '시군구'], axis=1)
p

# %%
p.columns

# %%
## 컬럼명 변경

p = p.rename(columns={'주소':'address',
                  '2019.01':'m01avg', '2019.02':'m02avg', '2019.03':'m03avg', '2019.04':'m04avg', '2019.05':'m05avg', '2019.06':'m06avg',
                  '2019.07':'m07avg', '2019.08':'m08avg', '2019.09':'m09avg', '2019.1':'m10avg', '2019.11':'m11avg', '2019.12':'m12avg'})
p

# %%
p = p.round(0)
p

# %%
p.iloc[:, 1:] = p.iloc[:, 1:].astype('int')
p

# %%
p.dtypes

# %% [markdown]
# ## **DB저장 및 csv 파일 저장**

# %%
p.to_csv('data/fin/year2019.csv', index=False)

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

## 디비연결
db_connection_str = 'mysql+pymysql://root:1234@localhost:3306/howair'
db_connection = create_engine(db_connection_str)
conn = db_connection.connect()

# db_connection_str = 'mysql+pymysql://[db유저이름]:[db password]@[host address]/[db name]'

# %%
## 테이블에 데이터 입력

p.to_sql(name='year2019', con=db_connection, if_exists='replace', index=True) 

#if_exists = append #데이터 추가

# %% [markdown]
# ## **연도별 데이터 정제 : 2010 ~ 2018 / 2020**

# %%
# p = pd.read_csv('data/year_data/pm10_2010.csv', encoding='CP949', header=0, engine='python')
p = pd.read_csv('data/year_data/pm10_2020.csv', encoding='CP949', header=0, engine='python')
p
# Out:
#      구분(1) 구분(2) 구분(3) 구분(4) 2020.01 2020.02 2020.03 2020.04 2020.05 2020.06  \
# 0     도시대기    서울    중구    중구      41      40      41      39      32      33
# 1     도시대기    서울   종로구   종로구      43      42      43      42      34      36
# 2     도시대기    서울   중랑구   중랑구      42      41      45      43      34      38
# 3     도시대기    서울  동대문구  동대문구      39      39      40      39      31      34
# 4     도시대기    서울   은평구   은평구      39      38      46      47      37      37
# ..     ...   ...   ...   ...     ...     ...     ...     ...     ...     ...
# 576  도로변대기    충북    청주   복대동      50      48      48      47      35      37
# 577  도로변대기    충남    천안   성성동      66      58      57      51      44      43
# 578  도로변대기    전북    전주   서신동       -       -       -    40**      38      44
# 579  도로변대기    경남    창원   반송로      28      31      29      32      30      28
# 580  도로변대기    제주    제주   노형로      32      37      44      48      44      31
#
#     2020.07 2020.08 2020.09 2020.10 2020.11 2020.12
# 0        20      23      21      40      50      49
# 1        22      23      21      36      44      44
# 2        22      25      19      32      40      42
# 3        20      23      19      30      38      38
# 4        19      21      18      32      38      39
# ..      ...     ...     ...     ...     ...     ...
# 576      18      26      28      41      45      46
# 577      28      25      29      48      52      51
# 578      22      27      26      36      38      38
# 579      19      33      23      27      29      28
# 580      20      28      30      33      29      27
#
# [581 rows x 16 columns]

# %%
p

# %%
## 함수화
def edit_auto(p):
    p.rename(columns={'구분(1)':'대기오염 종류'},inplace=True)
    p.rename(columns={'구분(2)':'광역시도'},inplace=True)
    p.rename(columns={'구분(3)':'시군구'},inplace=True)
    p.rename(columns={'구분(4)':'읍면동'},inplace=True)
    
    p = p[p['대기오염 종류']=='도시대기']
    # print(p)
    
    cols = p.columns
    cols = cols[4:]
    
    # 아스트리카 제거
    for i in cols:
        for j in range(len(p)):
            if p[i][j][-1:] == '*':  #IndexError: invalid index to scalar variable.
                p[i][j] = p[i][j].rstrip('*')
                # print(p[i][j])
    print(p)
    #-인 것 조회했을 때, 안 나오면 정상적으로 수정된 것
    for i in cols:
        for j in range(len(p[i])):
            if p[i][j] == '-':
            # if df[i][j] != '-':
                # print(p[i][j])
                p[i][j] = 0
    print(p)
    ## 타입변환 : object -> int
    for i in cols:
        p[i] = p[i].astype(int)
    print(p.dtypes)

# %%
edit_auto(p)
# Out:
#     대기오염 종류 광역시도   시군구   읍면동 2016.01 2016.02 2016.03 2016.04 2016.05 2016.06  \
# 0      도시대기   서울    중구    중구      48      44      58      69      56      45
# 1      도시대기   서울   종로구   종로구      50      46      63      67      53      44
# 2      도시대기   서울   중랑구   중랑구      51      48      64      77      60      45
# 3      도시대기   서울  동대문구  동대문구      52      48      66      76      60      45
# 4      도시대기   서울   은평구   은평구      47      43      63      69      55      47
# ..      ...  ...   ...   ...     ...     ...     ...     ...     ...     ...
# 259    도시대기   경남    거제   아주동      43      47      51      58      54      40
# 260    도시대기   경남    사천   사천읍      45      45      47      52      47      35
# 261    도시대기   제주    제주   이도동      45      55      56      65      58      39
# 262    도시대기   제주    제주    연동      44      52      50      58      54      36
# 263    도시대기   제주   서귀포   동홍동      39      43      45      52      46      28
#
#     2016.07 2016.08 2016.09 2016.10 2016.11 2016.12
# 0        34      37      42      30      51      47
# 1        30      31      32      37      50      48
# 2        34      36      39      40      57      50
# 3        32      34      37      38      54      52
# 4        33      31      38      39      52      47
# ..      ...     ...     ...     ...     ...     ...
# 259      30      38      37      37      44      37
# 260      26      33      28      30      42      39
# 261      31      33      37      48      42      43
# 262      26      28      35      37      44      33
# 263      23      27      33      36      32      32
#
# [264 rows x 16 columns]
#     대기오염 종류 광역시도   시군구   읍면동 2016.01 2016.02 2016.03 2016.04 2016.05 2016.06  \
# 0      도시대기   서울    중구    중구      48      44      58      69      56      45
# 1      도시대기   서울   종로구   종로구      50      46      63      67      53      44
# 2      도시대기   서울   중랑구   중랑구      51      48      64      77      60      45
# 3      도시대기   서울  동대문구  동대문구      52      48      66      76      60      45
# 4      도시대기   서울   은평구   은평구      47      43      63      69      55      47
# ..      ...  ...   ...   ...     ...     ...     ...     ...     ...     ...
# 259    도시대기   경남    거제   아주동      43      47      51      58      54      40
# 260    도시대기   경남    사천   사천읍      45      45      47      52      47      35
# 261    도시대기   제주    제주   이도동      45      55      56      65      58      39
# 262    도시대기   제주    제주    연동      44      52      50      58      54      36
# 263    도시대기   제주   서귀포   동홍동      39      43      45      52      46      28
#
#     2016.07 2016.08 2016.09 2016.10 2016.11 2016.12
# 0        34      37      42      30      51      47
# 1        30      31      32      37      50      48
# 2        34      36      39      40      57      50
# 3        32      34      37      38      54      52
# 4        33      31      38      39      52      47
# ..      ...     ...     ...     ...     ...     ...
# 259      30      38      37      37      44      37
# 260      26      33      28      30      42      39
# 261      31      33      37      48      42      43
# 262      26      28      35      37      44      33
# 263      23      27      33      36      32      32
#
# [264 rows x 16 columns]
# 대기오염 종류    object
# 광역시도       object
# 시군구        object
# 읍면동        object
# 2016.01     int32
# 2016.02     int32
# 2016.03     int32
# 2016.04     int32
# 2016.05     int32
# 2016.06     int32
# 2016.07     int32
# 2016.08     int32
# 2016.09     int32
# 2016.10     int32
# 2016.11     int32
# 2016.12     int32
# dtype: object

# %%
p
# Out:
#     대기오염 종류 광역시도   시군구   읍면동 2016.01 2016.02 2016.03 2016.04 2016.05 2016.06  \
# 0      도시대기   서울    중구    중구      48      44      58      69      56      45
# 1      도시대기   서울   종로구   종로구      50      46      63      67      53      44
# 2      도시대기   서울   중랑구   중랑구      51      48      64      77      60      45
# 3      도시대기   서울  동대문구  동대문구      52      48      66      76      60      45
# 4      도시대기   서울   은평구   은평구      47      43      63      69      55      47
# ..      ...  ...   ...   ...     ...     ...     ...     ...     ...     ...
# 333   도로변대기   경기  시도평균    소계      59      56      74      80      62      49
# 334   도로변대기   충북    청주   복대동      61      58      81      89      78      65
# 335   도로변대기   충남    천안   성성동      50      42      56      58      50      53
# 336   도로변대기   전북    전주   금암동      56      59      72      83      59      50
# 337   도로변대기   경남    창원   반송로      45      43      54      63      51      40
#
#     2016.07 2016.08 2016.09 2016.10 2016.11 2016.12
# 0        34      37      42    30**      51      47
# 1        30      31     32*      37      50      48
# 2        34      36      39      40      57      50
# 3        32      34      37      38      54      52
# 4        33      31      38      39      52      47
# ..      ...     ...     ...     ...     ...     ...
# 333      35      38      44      45      61      59
# 334      37      37      46      55      68      61
# 335      36      51      47     53*     50*      54
# 336      38      44      46      51      69      62
# 337      29      36     47*      42      50      51
#
# [338 rows x 16 columns]

# %%
p.rename(columns={'구분(1)':'대기오염 종류'},inplace=True)
p.rename(columns={'구분(2)':'광역시도'},inplace=True)
p.rename(columns={'구분(3)':'시군구'},inplace=True)
p.rename(columns={'구분(4)':'읍면동'},inplace=True)
p
# Out:
#     대기오염 종류 광역시도   시군구   읍면동 2020.01 2020.02 2020.03 2020.04 2020.05 2020.06  \
# 0      도시대기   서울    중구    중구      41      40      41      39      32      33
# 1      도시대기   서울   종로구   종로구      43      42      43      42      34      36
# 2      도시대기   서울   중랑구   중랑구      42      41      45      43      34      38
# 3      도시대기   서울  동대문구  동대문구      39      39      40      39      31      34
# 4      도시대기   서울   은평구   은평구      39      38      46      47      37      37
# ..      ...  ...   ...   ...     ...     ...     ...     ...     ...     ...
# 576   도로변대기   충북    청주   복대동      50      48      48      47      35      37
# 577   도로변대기   충남    천안   성성동      66      58      57      51      44      43
# 578   도로변대기   전북    전주   서신동       -       -       -    40**      38      44
# 579   도로변대기   경남    창원   반송로      28      31      29      32      30      28
# 580   도로변대기   제주    제주   노형로      32      37      44      48      44      31
#
#     2020.07 2020.08 2020.09 2020.10 2020.11 2020.12
# 0        20      23      21      40      50      49
# 1        22      23      21      36      44      44
# 2        22      25      19      32      40      42
# 3        20      23      19      30      38      38
# 4        19      21      18      32      38      39
# ..      ...     ...     ...     ...     ...     ...
# 576      18      26      28      41      45      46
# 577      28      25      29      48      52      51
# 578      22      27      26      36      38      38
# 579      19      33      23      27      29      28
# 580      20      28      30      33      29      27
#
# [581 rows x 16 columns]

# %%
p = p[p['대기오염 종류']=='도시대기']
p
# Out:
#     대기오염 종류 광역시도   시군구   읍면동 2020.01 2020.02 2020.03 2020.04 2020.05 2020.06  \
# 0      도시대기   서울    중구    중구      41      40      41      39      32      33
# 1      도시대기   서울   종로구   종로구      43      42      43      42      34      36
# 2      도시대기   서울   중랑구   중랑구      42      41      45      43      34      38
# 3      도시대기   서울  동대문구  동대문구      39      39      40      39      31      34
# 4      도시대기   서울   은평구   은평구      39      38      46      47      37      37
# ..      ...  ...   ...   ...     ...     ...     ...     ...     ...     ...
# 471    도시대기   제주    제주    연동      35      39      40      45      38      28
# 472    도시대기   제주   서귀포   동홍동      26      30      31      41      35      25
# 473    도시대기   제주   서귀포   성산읍      30      33      33      39      34      27
# 474    도시대기   제주   서귀포   대정읍      33      35      35      41      38      31
# 475    도시대기   제주   서귀포   남원읍      25      31      32      40      33      26
#
#     2020.07 2020.08 2020.09 2020.10 2020.11 2020.12
# 0        20      23      21      40      50      49
# 1        22      23      21      36      44      44
# 2        22      25      19      32      40      42
# 3        20      23      19      30      38      38
# 4        19      21      18      32      38      39
# ..      ...     ...     ...     ...     ...     ...
# 471      20      24      28      33      31      29
# 472      19      31      25      29      27      21
# 473      16      29      25      29      26      20
# 474      23      36      29      33      30      25
# 475      19      30      20      26      25      22
#
# [476 rows x 16 columns]

# %%
cols = p.columns
cols = cols[4:]
cols
# Out:
# Index(['2020.01', '2020.02', '2020.03', '2020.04', '2020.05', '2020.06',
#        '2020.07', '2020.08', '2020.09', '2020.10', '2020.11', '2020.12'],
#       dtype='object')

# %%
# p.info()
p.head()
# p.dtypes
# Out:
#   대기오염 종류 광역시도   시군구   읍면동 2014.01 2014.02 2014.03 2014.04 2014.05 2014.06  \
# 0    도시대기   서울    중구  서소문동      57      57      61      57      63      38
# 1    도시대기   서울   종로구   효제동      52      52      57      54      59      36
# 2    도시대기   서울   중랑구   면목동      57      57      65      62      65      39
# 3    도시대기   서울  동대문구   용두동      57      57      64      60      64      38
# 4    도시대기   서울   은평구   불광동      56      57      60      56      62      37
#
#    2014.07  2014.08  2014.09 2014.10 2014.11 2014.12
# 0       39       29       29      34      43      43
# 1       36       27       27      37      50      48
# 2       39       30       28      34      46      44
# 3       38       29       28      33      43      42
# 4       39       29       29      29      39    53**

# %%
#확인
# for i in cols:
#     for j in range(len(df[i])):
#         if df[i][j][-1:] == '*':
#             # print(df[i][j])
#             df[i][j] = df[i][j].rstrip('*')
#             print(df[i][j])
            
for i in cols:
    for j in range(len(p[i])):
        # if p[i][j].endswith('*'): #AttributeError: 'numpy.int64' object has no attribute 'endswith'
        # if p.iloc[i][j][-1:] == '*': #TypeError: Cannot index by location index with a non-integer key
        if p[i][j][-1:] == '*':  #IndexError: invalid index to scalar variable.
            print(p[i][j])
# Out:
# 45*
# 53*
# 59*
# 61*
# 45**
# 51*
# 41*
# 40*
# 44*
# 33*
# 31**
# 43*
# 30*
# 33*
# 39*
# 27*
# 25*
# 22**
# 25**
# 20*
# 41**
# 45*
# 40*
# 58*
# 38*
# 36*
# 32*
# 35*
# 55**
# 44**
# 42*
# 40*
# 38**
# 37**
# 24**
# 35**
# 18**
# 34**
# 25**
# 41**
# 33*
# 30**
# 34*
# 27**
# 33**
# 33**
# 36**
# 40**
# 42**
# 63**
# 46*
# 36*
# 39**
# 39**
# 33**
# 50**
# 47*
# 44**
# 37**

# %%
# p.iloc[10][0][-1:]
p[p['2014.12'].str.contains('*')]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # p.iloc[10][0][-1:]
# ----> 2 p[p['2014.12'].str.contains('*')]
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:1214, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1089 @forbid_nonstring_types(["bytes"])
#    1090 def contains(self, pat, case=True, flags=0, na=None, regex=True):
#    1091     r"""
#    1092     Test if pattern or regex is contained within a string of a Series or Index.
#    1093
#    (...)
#    1212     dtype: bool
#    1213     """
# -> 1214     if regex and re.compile(pat).groups:
#    1215         warnings.warn(
#    1216             "This pattern is interpreted as a regular expression, and has "
#    1217             "match groups. To actually get the groups, use str.extract.",
#    1218             UserWarning,
#    1219             stacklevel=find_stack_level(),
#    1220         )
#    1222     result = self._data.array._str_contains(pat, case, flags, na, regex)
#
# File ~\anaconda3\lib\re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File ~\anaconda3\lib\re.py:304, in _compile(pattern, flags)
#     302 if not sre_compile.isstring(pattern):
#     303     raise TypeError("first argument must be string or compiled pattern")
# --> 304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#     306     if len(_cache) >= _MAXCACHE:
#     307         # Drop the oldest item
#
# File ~\anaconda3\lib\sre_compile.py:764, in compile(p, flags)
#     762 if isstring(p):
#     763     pattern = p
# --> 764     p = sre_parse.parse(p, flags)
#     765 else:
#     766     pattern = None
#
# File ~\anaconda3\lib\sre_parse.py:950, in parse(str, flags, state)
#     947 state.str = str
#     949 try:
# --> 950     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     951 except Verbose:
#     952     # the VERBOSE flag was switched on inside the pattern.  to be
#     953     # on the safe side, we'll parse the whole thing again...
#     954     state = State()
#
# File ~\anaconda3\lib\sre_parse.py:443, in _parse_sub(source, state, verbose, nested)
#     441 start = source.tell()
#     442 while True:
# --> 443     itemsappend(_parse(source, state, verbose, nested + 1,
#     444                        not nested and not items))
#     445     if not sourcematch("|"):
#     446         break
#
# File ~\anaconda3\lib\sre_parse.py:668, in _parse(source, state, verbose, nested, first)
#     666     item = None
#     667 if not item or item[0][0] is AT:
# --> 668     raise source.error("nothing to repeat",
#     669                        source.tell() - here + len(this))
#     670 if item[0][0] in _REPEATCODES:
#     671     raise source.error("multiple repeat",
#     672                        source.tell() - here + len(this))
#
# error: nothing to repeat at position 0

# %%
#아스트리카 제거
## 기존 코드 : #IndexError: invalid index to scalar variable.
# for i in cols:
    # p[i] = p[i].astype("string")
    
#해결 : 자료형을 string으로 변환 후 하니까 먹힘
for i in cols:
    for j in range(len(p)):
        if p[i][j][-1:] == '*':  #IndexError: invalid index to scalar variable.
            p[i][j] = p[i][j].rstrip('*')
            print(p[i][j])
# Out:
# 44
# 35
# 38
# 55
# 53
# 29
# 39
# 61
# 40
# 46
# 20
# 36
# 37
# 37
# 50
# 45
# 48
# 39
# 40
# 37
# 32
# 31
# 30
# 33
# 65
# 45
# 42
# 42
# 48
# 33
# 47
# 37
# 37
# 42
# 28
# 33
# 32
# 32
# 25
# 49
# 59
# 34
# 26
# 26
# 26
# 19
# 23
# 24
# 18
# 23
# 21
# 25
# 12
# 14
# 13
# 16
# 15
# 23
# 35
# 25
# 28
# 27
# 21
# 24
# 22
# 14
# 17
# 16
# 22
# 34
# 18
# 27
# 17
# 29
# 18
# 36
# 23
# 20
# 30
# 23
# 23
# 21
# 19
# 17
# 24
# 19
# 29
# 31
# 28
# 37
# 35
# 42
# 42
# 38
# 40
# 40
# 34
# 31
# 22
# 18
# 39
# 27
# 43
# 37
# 38
# 33
# 67
# 46
# 24
# 22
# 26
# 21
# 41
# 35
# 24
# 31
# 24
# 19
# 23
# 31
# 35
# 33
# 42
# 25
# 33
# 34
# 24
# 31
# 21
# 24
# 41
# 28
# 28
# 26
# 30

# %%
#-인 것 조회했을 때, 안 나오면 정상적으로 수정된 것
for i in cols:
    for j in range(len(p)):
        if p[i][j] =='-':
        # if df[i][j] != '-':
            # print(p[i][j])
            p[i][j] = '0'

# %%
p.dtypes
# Out:
# 대기오염 종류    object
# 광역시도       object
# 시군구        object
# 읍면동        object
# 2020.01     int32
# 2020.02     int32
# 2020.03     int32
# 2020.04     int32
# 2020.05     int32
# 2020.06     int32
# 2020.07     int32
# 2020.08     int32
# 2020.09     int32
# 2020.10     int32
# 2020.11     int32
# 2020.12     int32
# dtype: object

# %%
## 타입변환 : object -> int
for i in cols:
    # p[i] = p[i].astype("string")
    p[i] = p[i].astype(int)

# %%
p
# Out:
#     대기오염 종류 광역시도   시군구   읍면동  2015.01  2015.02  2015.03  2015.04  2015.05  \
# 0      도시대기   서울    중구  서소문동       47       85       72       46       45
# 1      도시대기   서울   종로구   효제동       54       98       79       49       52
# 2      도시대기   서울   중랑구   면목동       49       88       73       47       46
# 3      도시대기   서울  동대문구   용두동       48       82       70       44       44
# 4      도시대기   서울   은평구   불광동       51       88       70       43       43
# ..      ...  ...   ...   ...      ...      ...      ...      ...      ...
# 260    도시대기   경남    거제   아주동       39       56       53       44       46
# 261    도시대기   경남    사천   사천읍       43       60       50       33       40
# 262    도시대기   제주    제주   이도동       50       64       66       49       45
# 263    도시대기   제주    제주    연동       51       63       58       46       39
# 264    도시대기   제주   서귀포   동홍동       47       55       53       47       43
#
#      2015.06  2015.07  2015.08  2015.09  2015.10  2015.11  2015.12
# 0         34       30       34       26       43       31       45
# 1         42       35       36       28       44       33       49
# 2         33       29       32       26       43       32       47
# 3         32       27       31       27       46       34       49
# 4         32       29       33       28       45       33       46
# ..       ...      ...      ...      ...      ...      ...      ...
# 260       48       35       44       35       43       35       40
# 261       39       32       32       24       32       30       43
# 262       40       35       39       28       45       36       43
# 263       41       37       39       37       56       45       42
# 264       40       30       29       34       32       27       37
#
# [265 rows x 16 columns]

# %%
p['광역시도'].unique()
# Out:
# array(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
#광역시도 이름 -> 표준행정구역명 수정할 #딕셔너리
sido_name = {'서울':'서울특별시', '부산':'부산광역시', '대구':'대구광역시', '인천':'인천광역시', '광주':'광주광역시', '대전':'대전광역시', '울산':'울산광역시', '세종':'세종특별자치시',
              '경기':'경기도', '강원':'강원도', '경남':'경상남도', '경북':'경상북도', '충북':'충청북도', '충남':'충청남도', '전남':'전라남도', '전북':'전라북도', '제주':'제주특별자치도'}

# %%
#광역시도 이름 변경
p['광역시도'] = p['광역시도'].apply(lambda v: sido_name.get(v, v))
p['광역시도'].unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'], dtype=object)

# %%
p['시군구'].unique()
# Out:
# array(['중구', '종로구', '중랑구', '동대문구', '은평구', '마포구', '영등포구', '동작구', '관악구',
#        '강남구', '금천구', '강동구', '강북구', '성북구', '용산구', '광진구', '성동구', '도봉구',
#        '서대문구', '구로구', '서초구', '강서구', '송파구', '양천구', '노원구', '남구', '사상구',
#        '북구', '사하구', '부산진구', '연제구', '영도구', '금정구', '해운대구', '기장군', '수영구',
#        '동래구', '동구', '서구', '수성구', '달서구', '달성군', '남동구', '부평구', '옹진군', '계양구',
#        '강화군', '연수구', '미추홀구', '광산구', '대덕구', '유성구', '울주군', '세종', '수원', '안양',
#        '성남', '의정부', '광명', '안산', '평택', '과천', '구리', '의왕', '고양', '광주', '군포',
#        '시흥', '부천', '남양주', '용인', '김포', '오산', '하남', '화성', '양주', '동두천', '안성',
#        '이천', '파주', '포천', '여주', '연천', '가평', '양평', '양구', '고성', '정선', '횡성',
#        '춘천', '강릉', '원주', '동해', '삼척', '평창', '양양', '속초', '영월', '철원', '홍천',
#        '화천', '태백', '인제', '괴산', '음성', '청주', '충주', '제천', '단양', '진천', '옥천',
#        '영동', '증평', '보은', '천안', '당진', '서산', '아산', '논산', '태안', '보령', '홍성',
#        '공주', '부여', '청양', '금산', '예산', '계룡', '서천', '임실', '전주', '군산', '익산',
#        '남원', '정읍', '고창', '부안', '김제', '완주', '진안', '무주', '순창', '장수', '화순',
#        '여수', '광양', '순천', '목포', '영암', '나주', '담양', '장성', '해남', '영광', '장흥',
#        '진도', '완도', '함평', '고흥', '신안', '무안', '강진', '곡성', '구례', '보성', '영덕',
#        '영천', '의성', '포항', '구미', '김천', '경주', '안동', '영주', '경산', '상주', '칠곡',
#        '울진', '봉화', '울릉도', '고령', '군위', '성주', '예천', '청도', '청송', '영양', '문경',
#        '창원', '진주', '하동', '김해', '양산', '거제', '사천', '밀양', '통영', '거창', '함안',
#        '함양', '남해', '산청', '의령', '창녕', '합천', '제주', '서귀포'], dtype=object)

# %%
sigungu_name = {'세종':'세종특별자치시', 
               #경기도
               '수원':'수원시', '안양':'안양시', '성남':'성남시', '의정부':'의정부시', '광명':'광명시', '안산':'안산시', '평택':'평택시',
               '과천':'과천시', '구리':'구리시', '의왕':'의왕시', '고양':'고양시', '광주':'광주시', '군포':'군포시', '시흥':'시흥시', '부천':'부천시', '남양주':'남양주시', 
               '용인':'용인시', '김포':'김포시', '오산':'오산시', '하남':'하남시', '화성':'화성시', '양주':'양주시', '동두천':'동두천시', '안성':'안성시',
               '이천':'이천시', '파주':'파주시', '포천':'포천시', '여주':'여주시', '연천':'연천군', '가평':'가평군', '양평':'양평군', '옹진':'옹진군',
               #강원도
                '양구':'양구군', '고성':'고성군', '정선':'정선군', '횡성':'횡성군', '춘천':'춘천시', '강릉':'강릉시', '원주':'원주시', '동해':'동해시', '삼척':'삼척시',
                '평창':'평창군', '양양':'양양군', '속초':'속초시', '영월':'영월군', '철원':'철원시', '홍천':'홍천군', '화천':'화천군', '태백':'태백시', '인제':'인제군',
               #충청북도
               '괴산':'괴산군', '음성':'음성군', '청주':'청주시', '충주':'충주시', '제천':'제천시', '단양':'단양군', '진천':'진천시', '옥천':'옥천군', '영동':'영동군',
               '증평':'증평군', '보은':'보은시',
               #충청남도
               '천안':'천안시', '당진':'당진시', '서산':'서산시', '아산':'아산시', '논산':'논산시', '태안':'태안군', '보령':'보령시', '홍성':'홍성군', '공주':'공주시', 
               '부여':'부여군', '청양':'청양군', '금산':'금산군', '예산':'예산군', '계룡':'계룡시', '서천':'서천시',
                #전라북도
                '임실':'임실군', '전주':'전주시', '군산':'군산시', '익산':'익산시', '남원':'남원시', '정읍':'정읍시', '고창':'고창군', '부안':'부안군', '김제':'김제시',
                '완주':'완주군', '진안':'진안군', '무주':'무주군', '순창':'순창군', '장수':'장수군',
                #전라남도
                '화순':'화순군', '여수':'여수시', '광양':'광양시', '순천':'순천시', '목포':'목포시', '영암':'영암군', '나주':'나주시', '담양':'담양군', '장성':'장성군',
                '해남':'해남군', '영광':'영광군', '장흥':'장흥군', '진도':'진도군', '완도':'완도군', '함평':'함평군', '고흥':'고흥군', '신안':'신안군', '무안':'무안군',
                '강진':'강진군', '곡성':'곡성군', '구례':'구례군', '보성':'보성군',
                #경상북도
                '영덕':'영덕군', '영천':'영천시', '의성':'의성군', '포항':'포항시', '구미':'구미시', '김천':'김천시', '경주':'경주시', '안동':'안동시', '영주':'영주시',
                '경산':'경산시', '상주':'상주시', '칠곡':'칠곡군', '울진':'울진군', '봉화':'봉화군', '울릉도':'울릉군', '고령':'고령군', '군위':'군위군', '성주':'성주군',
                '예천':'예천군', '청도':'청도군', '청송':'청송군', '영양':'영양군', '문경':'문경시',
                #경상남도
                '창원':'창원시', '진주':'진주시', '하동':'하동군', '김해':'김해시', '양산':'양산시', '거제':'거제시', '사천':'사천시', '밀양':'밀양시', '통영':'통영시',
                '거창':'거창군', '함안':'함안군', '함양':'함양군', '남해':'남해군', '산청':'산청군', '의령':'의령군', '창녕':'창녕군', '합천':'합천군',
                #제주특별자치도
                '제주':'제주시', '서귀포':'서귀포시'
               }

# %%
p['시군구'] = p['시군구'].apply(lambda v: sigungu_name.get(v, v))
p['시군구'].unique()

#누락
#2010 : 청원 / 마산 / 진해
#2011 : 청원 / 마산 / 진해
#2012 : 청원 / 마산 / 진해
#2013 : 청원 / 마산 / 진해
#2014 : 청원 / 마산 / 진해
#2018 : 청원 /
# Out:
# array(['중구', '종로구', '중랑구', '동대문구', '은평구', '마포구', '영등포구', '동작구', '관악구',
#        '강남구', '금천구', '강동구', '강북구', '성북구', '용산구', '광진구', '성동구', '도봉구',
#        '서대문구', '구로구', '서초구', '강서구', '송파구', '양천구', '노원구', '남구', '사상구',
#        '북구', '사하구', '부산진구', '연제구', '영도구', '금정구', '해운대구', '기장군', '수영구',
#        '동래구', '동구', '서구', '수성구', '달서구', '달성군', '남동구', '부평구', '옹진군', '계양구',
#        '강화군', '연수구', '미추홀구', '광산구', '대덕구', '유성구', '울주군', '세종특별자치시', '수원시',
#        '안양시', '성남시', '의정부시', '광명시', '안산시', '평택시', '과천시', '구리시', '의왕시',
#        '고양시', '광주시', '군포시', '시흥시', '부천시', '남양주시', '용인시', '김포시', '오산시',
#        '하남시', '화성시', '양주시', '동두천시', '안성시', '이천시', '파주시', '포천시', '여주시',
#        '연천군', '가평군', '양평군', '양구군', '고성군', '정선군', '횡성군', '춘천시', '강릉시',
#        '원주시', '동해시', '삼척시', '평창군', '양양군', '속초시', '영월군', '철원시', '홍천군',
#        '화천군', '태백시', '인제군', '괴산군', '음성군', '청주시', '충주시', '제천시', '단양군',
#        '진천시', '옥천군', '영동군', '증평군', '보은시', '천안시', '당진시', '서산시', '아산시',
#        '논산시', '태안군', '보령시', '홍성군', '공주시', '부여군', '청양군', '금산군', '예산군',
#        '계룡시', '서천시', '임실군', '전주시', '군산시', '익산시', '남원시', '정읍시', '고창군',
#        '부안군', '김제시', '완주군', '진안군', '무주군', '순창군', '장수군', '화순군', '여수시',
#        '광양시', '순천시', '목포시', '영암군', '나주시', '담양군', '장성군', '해남군', '영광군',
#        '장흥군', '진도군', '완도군', '함평군', '고흥군', '신안군', '무안군', '강진군', '곡성군',
#        '구례군', '보성군', '영덕군', '영천시', '의성군', '포항시', '구미시', '김천시', '경주시',
#        '안동시', '영주시', '경산시', '상주시', '칠곡군', '울진군', '봉화군', '울릉군', '고령군',
#        '군위군', '성주군', '예천군', '청도군', '청송군', '영양군', '문경시', '창원시', '진주시',
#        '하동군', '김해시', '양산시', '거제시', '사천시', '밀양시', '통영시', '거창군', '함안군',
#        '함양군', '남해군', '산청군', '의령군', '창녕군', '합천군', '제주시', '서귀포시'],
#       dtype=object)

# %% [markdown]
# ### **행정구역명 변동**
# - 충청북도 청원군 -> 충청북도 청주시
# - 경상남도 마산시 -> 경상남도 창원시 마산합포구 / 마산회원구

# %%
p[p['시군구'] =='강릉시']

# %%
p[p['시군구'] =='청원'] #176 #청주시   #181
# p[p['시군구'] =='마산'] #226, 227 #창원시  #235, 236  #236, 237
# p[p['시군구'] =='진해'] #231 #창원시         240  #241
# Out:
#     대기오염 종류  광역시도 시군구  읍면동  2018.01  2018.02  2018.03  2018.04  2018.05  \
# 213    도시대기  충청북도  청원  오창읍        0        0        0        0        0
#
#      2018.06  2018.07  2018.08  2018.09  2018.10  2018.11  2018.12
# 213        0       31       23       29        0        0        0

# %%
p.to_csv('data/year_data/2010.csv', index=False)

# %%
p = pd.read_csv('data/year_data/2010.csv', encoding='utf-8', header=0, engine='python')
p

# %%
### 데이터 변경

# p.iloc[176][2] = '청주시'

p = p.replace('청원', '청주시')
# p = p.replace('마산', '창원시')
# p = p.replace('진해', '창원시')

# %%
#데이터 변경 체크
# p.iloc[176][2]
p.iloc[213]
# Out:
# 대기오염 종류    도시대기
# 광역시도       충청북도
# 시군구         청주시
# 읍면동         오창읍
# 2018.01       0
# 2018.02       0
# 2018.03       0
# 2018.04       0
# 2018.05       0
# 2018.06       0
# 2018.07      31
# 2018.08      23
# 2018.09      29
# 2018.10       0
# 2018.11       0
# 2018.12       0
# Name: 213, dtype: object

# %% [markdown]
# #### **시군구별 중복 읍면동 평군 구하기**
# - address : 광역시도, 시군구 병합
# - groupby : 중복 시군구 평균 구하기

# %%
p['address'] = p.apply(lambda r: r['광역시도']+' '+r['시군구'], axis=1)
p
# Out:
#     대기오염 종류     광역시도   시군구   읍면동  2020.01  2020.02  2020.03  2020.04  2020.05  \
# 0      도시대기    서울특별시    중구    중구       41       40       41       39       32
# 1      도시대기    서울특별시   종로구   종로구       43       42       43       42       34
# 2      도시대기    서울특별시   중랑구   중랑구       42       41       45       43       34
# 3      도시대기    서울특별시  동대문구  동대문구       39       39       40       39       31
# 4      도시대기    서울특별시   은평구   은평구       39       38       46       47       37
# ..      ...      ...   ...   ...      ...      ...      ...      ...      ...
# 471    도시대기  제주특별자치도   제주시    연동       35       39       40       45       38
# 472    도시대기  제주특별자치도  서귀포시   동홍동       26       30       31       41       35
# 473    도시대기  제주특별자치도  서귀포시   성산읍       30       33       33       39       34
# 474    도시대기  제주특별자치도  서귀포시   대정읍       33       35       35       41       38
# 475    도시대기  제주특별자치도  서귀포시   남원읍       25       31       32       40       33
#
#      2020.06  2020.07  2020.08  2020.09  2020.10  2020.11  2020.12  \
# 0         33       20       23       21       40       50       49
# 1         36       22       23       21       36       44       44
# 2         38       22       25       19       32       40       42
# 3         34       20       23       19       30       38       38
# 4         37       19       21       18       32       38       39
# ..       ...      ...      ...      ...      ...      ...      ...
# 471       28       20       24       28       33       31       29
# 472       25       19       31       25       29       27       21
# 473       27       16       29       25       29       26       20
# 474       31       23       36       29       33       30       25
# 475       26       19       30       20       26       25       22
#
#           address
# 0        서울특별시 중구
# 1       서울특별시 종로구
# 2       서울특별시 중랑구
# 3      서울특별시 동대문구
# 4       서울특별시 은평구
# ..            ...
# 471   제주특별자치도 제주시
# 472  제주특별자치도 서귀포시
# 473  제주특별자치도 서귀포시
# 474  제주특별자치도 서귀포시
# 475  제주특별자치도 서귀포시
#
# [476 rows x 17 columns]

# %%
p_mean = p.groupby('address').mean()
p_mean
# Out:
#             2020.01  2020.02    2020.03  2020.04    2020.05  2020.06  \
# address
# 강원도 강릉시   25.000000    32.00  36.000000   38.000  32.000000    42.00
# 강원도 고성군   23.000000    28.00  32.000000   34.000  27.000000    33.00
# 강원도 동해시   21.000000    28.00  30.000000   32.000  27.000000    30.00
# 강원도 삼척시   22.000000    28.00  30.000000   32.000  28.000000    32.00
# 강원도 속초시   12.500000    16.00  18.500000   20.500  16.500000    20.00
# ...             ...      ...        ...      ...        ...      ...
# 충청북도 제천시  14.333333    13.00  12.666667   11.000   9.333333     0.00
# 충청북도 증평군  50.000000    42.00  38.000000   40.000  42.000000    45.00
# 충청북도 진천시  23.500000    21.50  46.500000   46.500  38.500000    40.00
# 충청북도 청주시  35.625000    33.75  39.250000   39.125  31.625000    32.25
# 충청북도 충주시  24.750000    23.00  43.250000   46.750  36.250000    38.75
#
#             2020.07    2020.08    2020.09    2020.10    2020.11    2020.12
# address
# 강원도 강릉시   14.000000  17.000000  27.000000  31.000000  32.000000  30.000000
# 강원도 고성군   14.000000  16.000000  19.000000  28.000000  22.000000  25.000000
# 강원도 동해시   16.000000  22.000000  21.000000  25.000000  26.000000  25.000000
# 강원도 삼척시   16.000000  22.000000  21.000000  24.000000  23.000000  19.000000
# 강원도 속초시   11.000000  11.000000  13.000000  16.000000  20.500000  16.500000
# ...             ...        ...        ...        ...        ...        ...
# 충청북도 제천시  16.666667  19.333333  20.333333  36.666667  39.333333  43.333333
# 충청북도 증평군  22.000000  30.000000  32.000000  43.000000  46.000000  48.000000
# 충청북도 진천시  20.500000  21.500000  22.500000  37.000000  44.000000  42.000000
# 충청북도 청주시  19.500000  22.000000  24.750000  41.500000  45.250000  46.500000
# 충청북도 충주시  19.000000  21.250000  20.000000  35.000000  41.250000  44.000000
#
# [229 rows x 12 columns]

# %%
p_mean = p_mean.rename(columns={
                  '2020.01':'m01avg', '2020.02':'m02avg', '2020.03':'m03avg', '2020.04':'m04avg', '2020.05':'m05avg', '2020.06':'m06avg',
                  '2020.07':'m07avg', '2020.08':'m08avg', '2020.09':'m09avg', '2020.10':'m10avg', '2020.11':'m11avg', '2020.12':'m12avg'})
p_mean
# Out:
#              m01avg  m02avg     m03avg  m04avg     m05avg  m06avg     m07avg  \
# address
# 강원도 강릉시   25.000000   32.00  36.000000  38.000  32.000000   42.00  14.000000
# 강원도 고성군   23.000000   28.00  32.000000  34.000  27.000000   33.00  14.000000
# 강원도 동해시   21.000000   28.00  30.000000  32.000  27.000000   30.00  16.000000
# 강원도 삼척시   22.000000   28.00  30.000000  32.000  28.000000   32.00  16.000000
# 강원도 속초시   12.500000   16.00  18.500000  20.500  16.500000   20.00  11.000000
# ...             ...     ...        ...     ...        ...     ...        ...
# 충청북도 제천시  14.333333   13.00  12.666667  11.000   9.333333    0.00  16.666667
# 충청북도 증평군  50.000000   42.00  38.000000  40.000  42.000000   45.00  22.000000
# 충청북도 진천시  23.500000   21.50  46.500000  46.500  38.500000   40.00  20.500000
# 충청북도 청주시  35.625000   33.75  39.250000  39.125  31.625000   32.25  19.500000
# 충청북도 충주시  24.750000   23.00  43.250000  46.750  36.250000   38.75  19.000000
#
#              m08avg     m09avg     m10avg     m11avg     m12avg
# address
# 강원도 강릉시   17.000000  27.000000  31.000000  32.000000  30.000000
# 강원도 고성군   16.000000  19.000000  28.000000  22.000000  25.000000
# 강원도 동해시   22.000000  21.000000  25.000000  26.000000  25.000000
# 강원도 삼척시   22.000000  21.000000  24.000000  23.000000  19.000000
# 강원도 속초시   11.000000  13.000000  16.000000  20.500000  16.500000
# ...             ...        ...        ...        ...        ...
# 충청북도 제천시  19.333333  20.333333  36.666667  39.333333  43.333333
# 충청북도 증평군  30.000000  32.000000  43.000000  46.000000  48.000000
# 충청북도 진천시  21.500000  22.500000  37.000000  44.000000  42.000000
# 충청북도 청주시  22.000000  24.750000  41.500000  45.250000  46.500000
# 충청북도 충주시  21.250000  20.000000  35.000000  41.250000  44.000000
#
# [229 rows x 12 columns]

# %%
p = p_mean.reset_index(drop=False, inplace=False)
p
# Out:
#       address     m01avg  m02avg     m03avg  m04avg     m05avg  m06avg  \
# 0     강원도 강릉시  25.000000   32.00  36.000000  38.000  32.000000   42.00
# 1     강원도 고성군  23.000000   28.00  32.000000  34.000  27.000000   33.00
# 2     강원도 동해시  21.000000   28.00  30.000000  32.000  27.000000   30.00
# 3     강원도 삼척시  22.000000   28.00  30.000000  32.000  28.000000   32.00
# 4     강원도 속초시  12.500000   16.00  18.500000  20.500  16.500000   20.00
# ..        ...        ...     ...        ...     ...        ...     ...
# 224  충청북도 제천시  14.333333   13.00  12.666667  11.000   9.333333    0.00
# 225  충청북도 증평군  50.000000   42.00  38.000000  40.000  42.000000   45.00
# 226  충청북도 진천시  23.500000   21.50  46.500000  46.500  38.500000   40.00
# 227  충청북도 청주시  35.625000   33.75  39.250000  39.125  31.625000   32.25
# 228  충청북도 충주시  24.750000   23.00  43.250000  46.750  36.250000   38.75
#
#         m07avg     m08avg     m09avg     m10avg     m11avg     m12avg
# 0    14.000000  17.000000  27.000000  31.000000  32.000000  30.000000
# 1    14.000000  16.000000  19.000000  28.000000  22.000000  25.000000
# 2    16.000000  22.000000  21.000000  25.000000  26.000000  25.000000
# 3    16.000000  22.000000  21.000000  24.000000  23.000000  19.000000
# 4    11.000000  11.000000  13.000000  16.000000  20.500000  16.500000
# ..         ...        ...        ...        ...        ...        ...
# 224  16.666667  19.333333  20.333333  36.666667  39.333333  43.333333
# 225  22.000000  30.000000  32.000000  43.000000  46.000000  48.000000
# 226  20.500000  21.500000  22.500000  37.000000  44.000000  42.000000
# 227  19.500000  22.000000  24.750000  41.500000  45.250000  46.500000
# 228  19.000000  21.250000  20.000000  35.000000  41.250000  44.000000
#
# [229 rows x 13 columns]

# %%
p = p.round(0)
p
# Out:
#       address  m01avg  m02avg  m03avg  m04avg  m05avg  m06avg  m07avg  m08avg  \
# 0     강원도 강릉시    25.0    32.0    36.0    38.0    32.0    42.0    14.0    17.0
# 1     강원도 고성군    23.0    28.0    32.0    34.0    27.0    33.0    14.0    16.0
# 2     강원도 동해시    21.0    28.0    30.0    32.0    27.0    30.0    16.0    22.0
# 3     강원도 삼척시    22.0    28.0    30.0    32.0    28.0    32.0    16.0    22.0
# 4     강원도 속초시    12.0    16.0    18.0    20.0    16.0    20.0    11.0    11.0
# ..        ...     ...     ...     ...     ...     ...     ...     ...     ...
# 224  충청북도 제천시    14.0    13.0    13.0    11.0     9.0     0.0    17.0    19.0
# 225  충청북도 증평군    50.0    42.0    38.0    40.0    42.0    45.0    22.0    30.0
# 226  충청북도 진천시    24.0    22.0    46.0    46.0    38.0    40.0    20.0    22.0
# 227  충청북도 청주시    36.0    34.0    39.0    39.0    32.0    32.0    20.0    22.0
# 228  충청북도 충주시    25.0    23.0    43.0    47.0    36.0    39.0    19.0    21.0
#
#      m09avg  m10avg  m11avg  m12avg
# 0      27.0    31.0    32.0    30.0
# 1      19.0    28.0    22.0    25.0
# 2      21.0    25.0    26.0    25.0
# 3      21.0    24.0    23.0    19.0
# 4      13.0    16.0    20.0    16.0
# ..      ...     ...     ...     ...
# 224    20.0    37.0    39.0    43.0
# 225    32.0    43.0    46.0    48.0
# 226    22.0    37.0    44.0    42.0
# 227    25.0    42.0    45.0    46.0
# 228    20.0    35.0    41.0    44.0
#
# [229 rows x 13 columns]

# %% [markdown]
# ## save : CSV 파일  / DB - MySQL

# %%
p.to_csv('data/fin/year2020.csv', index=False)

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

## 디비연결
db_connection_str = 'mysql+pymysql://root:1234@localhost:3306/howair'
db_connection = create_engine(db_connection_str)
conn = db_connection.connect()

# db_connection_str = 'mysql+pymysql://[db유저이름]:[db password]@[host address]/[db name]'

# %%
## 테이블에 데이터 입력

p.to_sql(name='year2020', con=db_connection, if_exists='replace', index=True) 

#if_exists = append #데이터 추가
# Out:
# 229
